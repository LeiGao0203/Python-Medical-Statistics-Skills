# %% [markdown]
# # Experiment Title

# %% [markdown]
# ## Objective
#
# State the clinical or statistical question, the target population, and the primary outcome before loading data.

# %%
import math
import statistics
from pathlib import Path

import numpy as np
import pandas as pd

# %% [markdown]
# ## Analysis Plan
#
# - Define inclusion and exclusion criteria.
# - Identify estimands, covariates, and planned sensitivity checks.
# - Record assumptions before viewing results.
