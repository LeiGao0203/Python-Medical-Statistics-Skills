# %% [markdown]
# # Tutorial Title

# %% [markdown]
# ## Learning Goals
#
# By the end of this tutorial, the learner should be able to describe the method, run the core analysis, and interpret the result in a medical statistics context.

# %%
import math
import statistics
from pathlib import Path

import numpy as np
import pandas as pd

# %% [markdown]
# ## Worked Example
#
# Introduce a small dataset, show each transformation, and connect every calculation to the clinical interpretation.
